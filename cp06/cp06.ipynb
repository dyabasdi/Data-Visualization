# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data file and create data frame
df = pd.read_csv("cars_clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                122  alfa-romero       gas        std
# 1           1          3                122  alfa-romero       gas        std
# 2           2          1                122  alfa-romero       gas        std
# 3           3          2                164         audi       gas        std
# 4           4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make fuel-type aspiration  \
# 196         196         -1                 95  volvo       gas        std
# 197         197         -1                 95  volvo       gas      turbo
# 198         198         -1                 95  volvo       gas        std
# 199         199         -1                 95  volvo    diesel      turbo
# 200         200         -1                 95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 196         four      sedan          rwd           front  ...          141
# 197         four      sedan          rwd           front  ...          141
# 198         four      sedan          rwd           front  ...          173
# 199         four      sedan          rwd           front  ...          145
# 200         four      sedan          rwd           front  ...          141
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized-losses  201 non-null    int64
#  3   make               201 non-null    object
#  4   fuel-type          201 non-null    object
#  5   aspiration         201 non-null    object
#  6   num-of-doors       201 non-null    object
#  7   body-style         201 non-null    object
#  8   drive-wheels       201 non-null    object
#  9   engine-location    201 non-null    object
#  10  wheel-base         201 non-null    float64
#  11  length             201 non-null    float64
#  12  width              201 non-null    float64
#  13  height             201 non-null    float64
#  14  curb-weight        201 non-null    int64
#  15  engine-type        201 non-null    object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                122  alfa-romero       gas
# 1             1          3                122  alfa-romero       gas
# 2             2          1                122  alfa-romero       gas
# 3             3          2                164         audi       gas
# 4             4          2                164         audi       gas
# ..          ...        ...                ...          ...       ...
# 196         196         -1                 95        volvo       gas
# 197         197         -1                 95        volvo       gas
# 198         198         -1                 95        volvo       gas
# 199         199         -1                 95        volvo    diesel
# 200         200         -1                 95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %% [markdown]
# ### Find Correlations Among Columns

# %%
df.corr(numeric_only= True)
# Out:
#                    Unnamed: 0  symboling  normalized-losses  wheel-base  \
# Unnamed: 0           1.000000  -0.162764          -0.241092    0.125517
# symboling           -0.162764   1.000000           0.466264   -0.535987
# normalized-losses   -0.241092   0.466264           1.000000   -0.056661
# wheel-base           0.125517  -0.535987          -0.056661    1.000000
# length               0.161848  -0.365404           0.019424    0.876024
# width                0.043976  -0.242423           0.086802    0.814507
# height               0.252015  -0.550160          -0.373737    0.590742
# curb-weight          0.064820  -0.233118           0.099404    0.782097
# engine-size         -0.047764  -0.110581           0.112360    0.572027
# bore                 0.244734  -0.140019          -0.029862    0.493244
# stroke              -0.162490  -0.008153           0.055045    0.158018
# compression-ratio    0.144301  -0.182196          -0.114713    0.250313
# ...

# %%
df[['horsepower', 'highway-mpg', 'engine-size', 'length', 'curb-weight']].corr(numeric_only=True)
# Out:
#              horsepower  highway-mpg  engine-size    length  curb-weight
# horsepower     1.000000    -0.804575     0.822676  0.579821     0.757976
# highway-mpg   -0.804575     1.000000    -0.679571 -0.698142    -0.794889
# engine-size    0.822676    -0.679571     1.000000  0.685025     0.849072
# length         0.579821    -0.698142     0.685025  1.000000     0.880665
# curb-weight    0.757976    -0.794889     0.849072  0.880665     1.000000

# %% [markdown]
# ### Relationships Among Data

# %%
# engine size (1), curb-weight(2), horsepower(3)

sns.regplot(x = 'engine-size', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 53139.269061407445)

# %%
sns.regplot(x = 'curb-weight', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 47759.795050601635)

# %%
sns.regplot(x = 'horsepower', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 47539.04168253935)

# %%
sns.regplot(x = 'highway-mpg', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 48173.64679074436)

# %%
sns.regplot(x = 'city-mpg', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 48237.81630335025)

# %%
sns.regplot(x = 'peak-rpm', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df.describe(include= ['object'])
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %%
# get the frequency distribution of make

df['make'].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# isuzu             2
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
# box plots for categorical

sns.boxplot(x = 'body-style', y= 'price', data= df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x = 'engine-location', y= 'price', data= df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x = 'drive-wheels', y= 'price', data= df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
sns.boxplot(x = 'make', y= 'price', data= df)
# Out:
# <Axes: xlabel='make', ylabel='price'>

# %%
sns.boxplot(x = 'num-of-cylinders', y= 'price', data= df)
# Out:
# <Axes: xlabel='num-of-cylinders', ylabel='price'>

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
# convert this to a dataframe
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns = {'drive-wheel': 'value_counts'}, inplace=True)
drive_wheels_counts.index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %% [markdown]
# ### Grouping Data

# %%
# create a group
group_1 = df[['make', 'price']]
grouped_mean_1 = group_1.groupby(['make'], as_index= False).mean()
print(grouped_mean_1)
# Out:
#              make         price
# 0     alfa-romero  15498.333333
# 1            audi  17859.166667
# 2             bmw  26118.750000
# 3       chevrolet   6007.000000
# 4           dodge   7875.444444
# 5           honda   8184.692308
# 6           isuzu   8916.500000
# 7          jaguar  34600.000000
# 8           mazda  10652.882353
# 9   mercedes-benz  33647.000000
# 10        mercury  16503.000000
# 11     mitsubishi   9239.769231
# 12         nissan  10415.666667
# 13         peugot  15489.090909
# 14       plymouth   7963.428571
# 15        porsche  31400.500000
# 16        renault   9595.000000
# 17           saab  15223.333333
# 18         subaru   8541.250000
# 19         toyota   9885.812500
# 20     volkswagen  10077.500000
# 21          volvo  18063.181818

# %%
# create another group
group_2 = df[['drive-wheels', 'engine-location', 'price']]
grouped_mean_2 = group_2.groupby(['drive-wheels', 'engine-location'], as_index= False).mean()
print(grouped_mean_2)
# Out:
#   drive-wheels engine-location         price
# 0          4wd           front  10241.000000
# 1          fwd           front   9244.779661
# 2          rwd           front  19142.180556
# 3          rwd            rear  34528.000000

# %% [markdown]
# ### Pivoting a Data Frame

# %%
grouped_pivot_1 = grouped_mean_2.pivot(index = 'drive-wheels', columns= 'engine-location')

# fill missing values with 0

grouped_pivot_1.fillna(0, inplace=True)
print(grouped_pivot_1)
# Out:
#                         price
# engine-location         front     rear
# drive-wheels
# 4wd              10241.000000      0.0
# fwd               9244.779661      0.0
# rwd              19142.180556  34528.0

# %%
# restructure the table
grouped_pivot_2 = grouped_mean_2.pivot(index= 'engine-location', columns='drive-wheels')
grouped_pivot_2.fillna(0, inplace=True)
print(grouped_pivot_2)
# Out:
#                    price
# drive-wheels         4wd          fwd           rwd
# engine-location
# front            10241.0  9244.779661  19142.180556
# rear                 0.0     0.000000  34528.000000

# %% [markdown]
# #### P-value

# %% [markdown]
# The probability that the correlation between two variables in statistically significant.
# * p < 0.001:    strong evidence that the correlation coefficient is significant.
# * p < 0.05:     moderate evidence that the correlation coefficient is significant.
# * p < 0.1:      weak evidence that the correlation coefficient is significant.
# * p > 0.1:      no evidence that the correlation coefficient is significant.

# %%
# import scipy stats library
from scipy import stats

# %%
# compute the correlation coefficient and the p-value for engine size
p_coef, p_val = stats.pearsonr(df['engine-size'], df['price'])
print(f"P_Coef: {p_coef}\n P_Val: {p_val}")
# Out:
# P_Coef: 0.8723351674455185
#  P_Val: 9.26549162219869e-64

# %% [markdown]
# Tight correlation - makes sense

# %% [markdown]
# #### Analysis of Variance (ANOVA)
# Analysis of Variance is a statistical method to test whether there are significant differences between two or more groups. ANOVA returns two parameters:
# * F-test Score
# * P-Value
#
# If our price variable is strongly correlated with the variable that we are analyzing, then we will expect ANOVA to return a large F-test score and a small p-value.

# %%
# check if there is a group 2
print(group_2)
# Out:
#     drive-wheels engine-location  price
# 0            rwd           front  13495
# 1            rwd           front  16500
# 2            rwd           front  16500
# 3            fwd           front  13950
# 4            4wd           front  17450
# ..           ...             ...    ...
# 196          rwd           front  16845
# 197          rwd           front  19045
# 198          rwd           front  21485
# 199          rwd           front  22470
# 200          rwd           front  22625
#
# [201 rows x 3 columns]

# %%
# make another group from group 2
group_3 = group_2[['drive-wheels', 'price']].groupby(['drive-wheels'])
group_3.head(3)
# Out:
#     drive-wheels  price
# 0            rwd  13495
# 1            rwd  16500
# 2            rwd  16500
# 3            fwd  13950
# 4            4wd  17450
# 5            fwd  15250
# 6            fwd  17710
# 136          4wd   7603
# 140          4wd   9233

# %%
group_3.get_group('4wd')['price']
# Out:
# C:\Users\dyaba\AppData\Local\Temp\ipykernel_18244\1203527767.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   group_3.get_group('4wd')['price']
# 4      17450
# 136     7603
# 140     9233
# 141    11259
# 144     8013
# 145    11694
# 150     7898
# 151     8778
# Name: price, dtype: int64

# %%
# run ANOVA on the different groups
f_val, p_val = stats.f_oneway(group_3.get_group('fwd')['price'],
                              group_3.get_group('4wd')['price'],
                              group_3.get_group('rwd')['price'],
                              )
print(f"ANOVA Results:\n - F_val: {f_val}\n - P_val: {p_val}")
# Out:
# ANOVA Results:
#  - F_val: 67.95406500780398
#  - P_val: 3.3945443577149576e-23
# C:\Users\dyaba\AppData\Local\Temp\ipykernel_18244\2890355039.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   f_val, p_val = stats.f_oneway(group_3.get_group('fwd')['price'],
# C:\Users\dyaba\AppData\Local\Temp\ipykernel_18244\2890355039.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   group_3.get_group('4wd')['price'],
# C:\Users\dyaba\AppData\Local\Temp\ipykernel_18244\2890355039.py:4: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# #### Linear Regression Model
#
# y = a + bx

# %%
# import scikit learn
from sklearn.linear_model import LinearRegression

# %%
# create a linear regression object
lm = LinearRegression()

# use engine-size first

X = df[['engine-size']]
Y = df['price']
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
# get slope and intercept
print(f"Slope: {lm.coef_}\nIntercept: {lm.intercept_}")
lm.score(X, Y)
# Out:
# Slope: [166.86001569]
# Intercept: -7963.338906281024
# 0.7609686443622008

# %% [markdown]
# Equation:
#
# y = 166.86x - 7963.34
#
# Price = 166.86 * engine-size - 7963.34

# %%
sns.regplot(x = 'engine-size', y= 'price', data = df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %% [markdown]
# Residual Plot

# %%
# output the predictions from the model

Yhat = lm.predict(X)
Yhat[0:5]
# Out:
# array([13728.4631336 , 13728.4631336 , 17399.38347881, 10224.40280408,
#        14729.62322775])

# %%
# compare with actual values by creating residual plot
sns.residplot(x = df['engine-size'], y = df['price'])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %% [markdown]
# #### Coefficient of determination
#
# R^2 Value indicates how well a model fits the data and predicts outcomes.

# %%
# coefficient of determination
print(f"R^2: {lm.score(X, Y)}")
# Out:
# R^2: 0.7609686443622008

# %% [markdown]
# ##### Multiple Linear Regression

# %%
# define the parameters to go into our model
Z = df[['engine-size', 'horsepower', 'peak-rpm', 'highway-mpg', 'city-mpg']]

lm_2 = LinearRegression()
lm_2.fit(Z, Y)
print(f"R^2: {lm_2.score(Z, Y)}")
# Out:
# R^2: 0.7938712381703784

# %%
print(lm_2.intercept_)
print(lm_2.coef_)
# Out:
# -6759.478508493907
# [ 131.52451364   30.08305957    0.87938573 -146.59822853    6.62426399]

# %% [markdown]
# ##### Equation for Multi-Variable Linear Regression Model
#
# price = -6759 + 132 * engine-size + 30 * horsepower + 0.879 * peak-rpm - 147 * highway-mpg + 6.62 * city-mpg

# %% [markdown]
# ### Polynomial Fit

# %%
# function to plot data
def plotPoly(model, x, y, Name):
    x_new = np.linspace(1400, 5000, 1000)
    y_new = model(x_new)

    plt.plot(x, y, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')
    plt.show()

# %%
# fit a quadratic to the data
x = df['curb-weight']
y = df['price']
f = np.polyfit(x, y, 2)
p = np.poly1d(f)
plotPoly(p, x, y, 'Curb Weight')
